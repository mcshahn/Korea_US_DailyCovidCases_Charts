# %%
import numpy as np
import pandas as pd
import os
import urllib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
url = "https://covid19.who.int/WHO-COVID-19-global-data.csv"
file_path = os.path.join("data", "covid")

# %%
os.makedirs(file_path, exist_ok = True)
csv_path = os.path.join(file_path, "WHO-COVID-19-global-data.csv")
urllib.request.urlretrieve(url,csv_path)
# Out:
# ('data/covid/WHO-COVID-19-global-data.csv',
#  <http.client.HTTPMessage at 0x7f8e6e338520>)

# %%
df = pd.read_csv(csv_path)

# %%
df
# Out:
#        Date_reported Country_code      Country WHO_region  New_cases  \
# 0         2020-01-03           AF  Afghanistan       EMRO          0
# 1         2020-01-04           AF  Afghanistan       EMRO          0
# 2         2020-01-05           AF  Afghanistan       EMRO          0
# 3         2020-01-06           AF  Afghanistan       EMRO          0
# 4         2020-01-07           AF  Afghanistan       EMRO          0
# ...              ...          ...          ...        ...        ...
# 185803    2022-02-20           ZW     Zimbabwe       AFRO        194
# 185804    2022-02-21           ZW     Zimbabwe       AFRO        128
# 185805    2022-02-22           ZW     Zimbabwe       AFRO        219
# 185806    2022-02-23           ZW     Zimbabwe       AFRO        409
# 185807    2022-02-24           ZW     Zimbabwe       AFRO        609
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# 0                      0           0                  0
# ...

# %%
df.describe()
# Out:
#           New_cases  Cumulative_cases     New_deaths  Cumulative_deaths
# count  1.858080e+05      1.858080e+05  185808.000000      185808.000000
# mean   2.306206e+03      5.076812e+05      31.812844       10542.880802
# std    1.575494e+04      2.800107e+06     165.890824       50073.451505
# min   -3.295200e+04      0.000000e+00     -60.000000           0.000000
# 25%    0.000000e+00      1.320000e+02       0.000000           1.000000
# 50%    2.200000e+01      8.696000e+03       0.000000         123.000000
# 75%    4.940000e+02      1.342015e+05       6.000000        2324.000000
# max    1.328614e+06      7.797422e+07    8786.000000      931612.000000

# %%
df.columns = [col.strip() for col in df.columns]

# %%
df
# Out:
#        Date_reported Country_code      Country WHO_region  New_cases  \
# 0         2020-01-03           AF  Afghanistan       EMRO          0
# 1         2020-01-04           AF  Afghanistan       EMRO          0
# 2         2020-01-05           AF  Afghanistan       EMRO          0
# 3         2020-01-06           AF  Afghanistan       EMRO          0
# 4         2020-01-07           AF  Afghanistan       EMRO          0
# ...              ...          ...          ...        ...        ...
# 185803    2022-02-20           ZW     Zimbabwe       AFRO        194
# 185804    2022-02-21           ZW     Zimbabwe       AFRO        128
# 185805    2022-02-22           ZW     Zimbabwe       AFRO        219
# 185806    2022-02-23           ZW     Zimbabwe       AFRO        409
# 185807    2022-02-24           ZW     Zimbabwe       AFRO        609
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# 0                      0           0                  0
# ...

# %%
korea = df[df.Country == 'Republic of Korea']
korea
# Out:
#        Date_reported Country_code            Country WHO_region  New_cases  \
# 134064    2020-01-03           KR  Republic of Korea       WPRO          0
# 134065    2020-01-04           KR  Republic of Korea       WPRO          0
# 134066    2020-01-05           KR  Republic of Korea       WPRO          0
# 134067    2020-01-06           KR  Republic of Korea       WPRO          0
# 134068    2020-01-07           KR  Republic of Korea       WPRO          0
# ...              ...          ...                ...        ...        ...
# 134843    2022-02-20           KR  Republic of Korea       WPRO     104814
# 134844    2022-02-21           KR  Republic of Korea       WPRO      95339
# 134845    2022-02-22           KR  Republic of Korea       WPRO      99569
# 134846    2022-02-23           KR  Republic of Korea       WPRO     171442
# 134847    2022-02-24           KR  Republic of Korea       WPRO     170016
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# ...

# %%
korea_newCases = korea.New_cases.values
dates = korea.Date_reported.values
print(dates.min())
print(dates.max())
# Out:
# 2020-01-03
# 2022-02-24

# %%
plt.title("Daily New Covid Cases in Korea from 2020-01-03 to 2022-02-24")
plt.suptitle("Plotted every 50 days")
plt.xlabel("Dates")
plt.ylabel("Number of New Cases")
plt.scatter(dates[::50], korea_newCases[::50])

# %%
us = df[df.Country == "United States of America"]
us_newCases = us.New_cases.values
dates = us.Date_reported.values
print(dates.min())
print(dates.max())
# Out:
# 2020-01-03
# 2022-02-24

# %%
plt.title("Daily New Covid Cases in the US from 2020-01-03 to 2022-02-24")
plt.suptitle("Plotted every 50 days")
plt.xlabel("Dates")
plt.ylabel("Number of New Cases")
plt.scatter(dates, us_newCases)
